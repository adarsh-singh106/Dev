# %% [markdown]
# ### 🎯 Mission: Perfect Centering
# *Goal: Center an item horizontally and vertically inside a container.*
#
# ```css
# /* =========================================
#    1. 🐢 THE STANDARD CSS WAY
#    (Requires 3 lines of CSS code)
#    ========================================= */
#
# .container {
#   display: flex;           /* Activate Flexbox */
#   justify-content: center; /* Center horizontally (X-axis) */
#   align-items: center;     /* Center vertically (Y-axis) */
# }
